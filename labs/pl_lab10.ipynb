# %% [markdown]
# # Lab 10: Projekt końcowy
#
# ## Cel
#
# Zbudowanie kompletnego systemu real-time w grupach max. 5-osobowych.
#
# | Kryterium | Waga |
# |---|---|
# | Działający pipeline (Kafka + przetwarzanie) | 30% |
# | Model ML zintegrowany z systemem | 25% |
# | Konteneryzacja (Docker Compose) | 20% |
# | Dokumentacja i jakość kodu | 15% |
# | Prezentacja | 10% |
#
# ---
#
# Szczegółowe zadania — patrz angielska wersja `en_lab10.ipynb` (identyczna struktura, tłumaczenie nazw zmiennych na polskie).

# %%
# Lab 10 — TWÓJ KOD
# Szczegółowe instrukcje w pełnej wersji notatnika

# %%
# Temat projektu: ...
# Członkowie zespołu: ...
